# %% [markdown]
# # Chapter 6. Social Media Insight Using Naive Bayes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import twitter
import json 

# https://apps.twitter.com/app/13142176/show
# confidentailな情報をうっかりgitにあげないように、別ファイルに書き出し
with open('./twitter.json','r') as file: 
    token=json.load(file)
authorization = twitter.OAuth(**token)

# twitterとのI/Fのためのオブジェクト
t=twitter.Twitter(auth=authorization)

# %%
# 検索データをファイルにアウトプット
output_file='./python_tweets.json'

with open(output_file,'a') as file:
    search_results=t.search.tweets(q='python',count=100)['statuses']
    
    for tweet in search_results:
        if 'text' in tweet:
            # オブジェクトをjsonに変換
            file.write(json.dumps(tweet))
            file.write('\n\n')

# %%
pd.DataFrame(search_results).head()
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Tue May 01 11:51:26 +0000 2018
# 1         None        None  Tue May 01 11:51:25 +0000 2018
# 2         None        None  Tue May 01 11:51:23 +0000 2018
# 3         None        None  Tue May 01 11:51:20 +0000 2018
# 4         None        None  Tue May 01 11:51:20 +0000 2018
#
#                                             entities extended_entities  \
# 0  {'hashtags': [{'text': 'Databricks', 'indices'...               NaN
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
#
#    favorite_count  favorited   geo                  id              id_str  \
# 0               0      False  None  991283953179951109  991283953179951109
# 1               0      False  None  991283949002412033  991283949002412033
# 2               0      False  None  991283941305860096  991283941305860096
# 3               0      False  None  991283929666633729  991283929666633729
# 4               0      False  None  991283928655974400  991283928655974400
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                        quoted_status  quoted_status_id  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3  {'created_at': 'Tue May 01 10:03:18 +0000 2018...      9.912567e+17
# 4                                                NaN               NaN
#
#   quoted_status_id_str  retweet_count retweeted  \
# 0                  NaN             20     False
# 1                  NaN              0     False
# 2                  NaN              0     False
# 3   991256740854353920              0     False
# 4                  NaN            151     False
#
#                                     retweeted_status  \
# 0  {'created_at': 'Mon Apr 30 22:35:07 +0000 2018...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  {'created_at': 'Tue May 01 06:29:44 +0000 2018...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com" rel="nofollow">Tw...
# 2  <a href="https://about.twitter.com/products/tw...
# 3  <a href="https://about.twitter.com/products/tw...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text truncated  \
# 0  RT @Azure: Azure #Databricks Notebooks allow l...     False
# 1                          ㅠ로롱님이 범꼬테 그리신거 봐요 넘이쁨 (땐싱     False
# 2                                pythonまわりも設定し直さなきゃか     False
# 3  今思いついたけど、\n\nli = input().split()\ns = li[0]\n...      True
# 4  RT @binitamshah: WinPwnage : A Collection of P...     False
#
#                                                 user
# 0  {'id': 16372254, 'id_str': '16372254', 'name':...
# 1  {'id': 753941053078503424, 'id_str': '75394105...
# 2  {'id': 753614565460484096, 'id_str': '75361456...
# 3  {'id': 2952301202, 'id_str': '2952301202', 'na...
# 4  {'id': 30004536, 'id_str': '30004536', 'name':...
#
# [5 rows x 30 columns]
